# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("ipl_main.csv", low_memory=False)
df.head()
# Out:
#          team1 team2       winner   margin     matchDate match_id  \
# 0  Super Kings   KKR  Super Kings  27 runs  Oct 15, 2021  T203817
# 1  Super Kings   KKR  Super Kings  27 runs  Oct 15, 2021  T203817
# 2  Super Kings   KKR  Super Kings  27 runs  Oct 15, 2021  T203817
# 3  Super Kings   KKR  Super Kings  27 runs  Oct 15, 2021  T203817
# 4  Super Kings   KKR  Super Kings  27 runs  Oct 15, 2021  T203817
#
#                 match bowlingTeam     bowlerName  overs  ...  teamInnings  \
# 0  Super Kings Vs KKR         KKR  ShakibAlHasan    3.0  ...  Super Kings
# 1  Super Kings Vs KKR         KKR  ShakibAlHasan    3.0  ...  Super Kings
# 2  Super Kings Vs KKR         KKR  ShakibAlHasan    3.0  ...  Super Kings
# 3  Super Kings Vs KKR         KKR  ShakibAlHasan    3.0  ...  Super Kings
# 4  Super Kings Vs KKR         KKR  ShakibAlHasan    3.0  ...          KKR
#
#    battingPos     batsmanName  out/not_out  balls      SR         team  \
# ...

# %%
df.shape
# Out:
# (38701, 29)

# %%
df.isnull().sum()
# Out:
# team1           0
# team2           0
# winner          0
# margin          0
# matchDate       0
# match_id        0
# match           0
# bowlingTeam     0
# bowlerName      0
# overs           0
# maiden          0
# runs            0
# wickets         0
# economy         0
# 0s              0
# 4s              0
# 6s              0
# wides           0
# noBalls         0
# teamInnings     0
# battingPos      0
# batsmanName     0
# out/not_out     0
# balls           0
# SR              0
# team            0
# battingStyle    0
# bowlingStyle    0
# playingRole     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['team1', 'team2', 'winner', 'margin', 'matchDate', 'match_id', 'match',
#        'bowlingTeam', 'bowlerName', 'overs', 'maiden', 'runs', 'wickets',
#        'economy', '0s', '4s', '6s', 'wides', 'noBalls', 'teamInnings',
#        'battingPos', 'batsmanName', 'out/not_out', 'balls', 'SR', 'team',
#        'battingStyle', 'bowlingStyle', 'playingRole'],
#       dtype='object')

# %%
df.info()
## match date data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38701 entries, 0 to 38700
# Data columns (total 29 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   team1         38701 non-null  object
#  1   team2         38701 non-null  object
#  2   winner        38701 non-null  object
#  3   margin        38701 non-null  object
#  4   matchDate     38701 non-null  object
#  5   match_id      38701 non-null  object
#  6   match         38701 non-null  object
#  7   bowlingTeam   38701 non-null  object
#  8   bowlerName    38701 non-null  object
#  9   overs         38701 non-null  float64
#  10  maiden        38701 non-null  int64
#  11  runs          38701 non-null  int64
#  12  wickets       38701 non-null  int64
#  13  economy       38701 non-null  float64
#  14  0s            38701 non-null  int64
#  15  4s            38701 non-null  int64
#  16  6s            38701 non-null  int64
#  17  wides         38701 non-null  int64
# ...

# %%
df.describe()
# Out:
#               overs        maiden          runs       wickets       economy  \
# count  38701.000000  38701.000000  38701.000000  38701.000000  38701.000000
# mean       3.260843      0.025400     27.335857      1.003540      8.679474
# std        1.019176      0.160589     11.158907      1.067932      3.311242
# min        0.100000      0.000000      0.000000      0.000000      0.000000
# 25%        3.000000      0.000000     20.000000      0.000000      6.500000
# 50%        4.000000      0.000000     27.000000      1.000000      8.250000
# 75%        4.000000      0.000000     35.000000      2.000000     10.500000
# max        4.000000      2.000000     69.000000      5.000000     36.000000
#
#                  0s            4s            6s         wides       noBalls  \
# count  38701.000000  38701.000000  38701.000000  38701.000000  38701.000000
# mean       7.405106      2.317692      1.159427      0.734038      0.101832
# ...

# %%
df.head()
# Out:
#          team1 team2       winner   margin     matchDate match_id  \
# 0  Super Kings   KKR  Super Kings  27 runs  Oct 15, 2021  T203817
# 1  Super Kings   KKR  Super Kings  27 runs  Oct 15, 2021  T203817
# 2  Super Kings   KKR  Super Kings  27 runs  Oct 15, 2021  T203817
# 3  Super Kings   KKR  Super Kings  27 runs  Oct 15, 2021  T203817
# 4  Super Kings   KKR  Super Kings  27 runs  Oct 15, 2021  T203817
#
#                 match bowlingTeam     bowlerName  overs  ...  teamInnings  \
# 0  Super Kings Vs KKR         KKR  ShakibAlHasan    3.0  ...  Super Kings
# 1  Super Kings Vs KKR         KKR  ShakibAlHasan    3.0  ...  Super Kings
# 2  Super Kings Vs KKR         KKR  ShakibAlHasan    3.0  ...  Super Kings
# 3  Super Kings Vs KKR         KKR  ShakibAlHasan    3.0  ...  Super Kings
# 4  Super Kings Vs KKR         KKR  ShakibAlHasan    3.0  ...          KKR
#
#    battingPos     batsmanName  out/not_out  balls      SR         team  \
# ...

# %%
# Convert the 'Date' column to datetime format using DataFrame.astype()
df['Date'] = df['Date'].astype('datetime64[ns]')

# Check the updated data type of the 'Date' column
print(df.info())

# %%
df['matchDate']=df['matchDate'].astype('datetime64[ns]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38701 entries, 0 to 38700
# Data columns (total 30 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   team1         38701 non-null  object
#  1   team2         38701 non-null  object
#  2   winner        38701 non-null  object
#  3   margin        38701 non-null  object
#  4   matchDate     38701 non-null  datetime64[ns]
#  5   match_id      38701 non-null  object
#  6   match         38701 non-null  object
#  7   bowlingTeam   38701 non-null  object
#  8   bowlerName    38701 non-null  object
#  9   overs         38701 non-null  float64
#  10  maiden        38701 non-null  int64
#  11  runs          38701 non-null  int64
#  12  wickets       38701 non-null  int64
#  13  economy       38701 non-null  float64
#  14  0s            38701 non-null  int64
#  15  4s            38701 non-null  int64
#  16  6s            38701 non-null  int64
#  17  wides         38701 non-null  int64
# ...

# %%
import datetime as dt
df['match_year']=df['matchDate'].dt.year

# %%
df.groupby(["match_year", "batsmanName"])['runs'].sum()
# Out:
# match_year  batsmanName
# 2021        ABdeVilliers      4178
#             AbdulSamad        3007
#             AbhishekSharma    1798
#             AdamMilne          871
#             AidenMarkram      1785
#                               ...
# 2029        RuturajGaikwad     382
#             SaiSudharsan       382
#             ShivamDube         382
#             ShubmanGill        382
#             WriddhimanSaha     382
# Name: runs, Length: 513, dtype: int64

# %%
df['match_year'].values
# Out:
# array([2021, 2021, 2021, ..., 2023, 2023, 2023])

# %%
df['match_year'].value_counts()
# Out:
# match_year
# 2023    14222
# 2022    13637
# 2021    10710
# 2029      132
# Name: count, dtype: int64

# %%
df[df['match_year'] != 2029].groupby('batsmanName')['runs'].sum().sort_values(ascending=False).head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='batsmanName'>

# %%
df.head()
# Out:
#          team1 team2       winner   margin  matchDate match_id  \
# 0  Super Kings   KKR  Super Kings  27 runs 2021-10-15  T203817
# 1  Super Kings   KKR  Super Kings  27 runs 2021-10-15  T203817
# 2  Super Kings   KKR  Super Kings  27 runs 2021-10-15  T203817
# 3  Super Kings   KKR  Super Kings  27 runs 2021-10-15  T203817
# 4  Super Kings   KKR  Super Kings  27 runs 2021-10-15  T203817
#
#                 match bowlingTeam     bowlerName  overs  ...  battingPos  \
# 0  Super Kings Vs KKR         KKR  ShakibAlHasan    3.0  ...           1
# 1  Super Kings Vs KKR         KKR  ShakibAlHasan    3.0  ...           2
# 2  Super Kings Vs KKR         KKR  ShakibAlHasan    3.0  ...           3
# 3  Super Kings Vs KKR         KKR  ShakibAlHasan    3.0  ...           4
# 4  Super Kings Vs KKR         KKR  ShakibAlHasan    3.0  ...           1
#
#       batsmanName  out/not_out  balls      SR         team    battingStyle  \
# ...

# %%
df.columns
# Out:
# Index(['team1', 'team2', 'winner', 'margin', 'matchDate', 'match_id', 'match',
#        'bowlingTeam', 'bowlerName', 'overs', 'maiden', 'runs', 'wickets',
#        'economy', '0s', '4s', '6s', 'wides', 'noBalls', 'teamInnings',
#        'battingPos', 'batsmanName', 'out/not_out', 'balls', 'SR', 'team',
#        'battingStyle', 'bowlingStyle', 'playingRole', 'match_year'],
#       dtype='object')

# %%
df[['runs', '0s', "4s", "6s"]]
# Out:
#        runs  0s  4s  6s
# 0        33   6   2   3
# 1        33   6   2   3
# 2        33   6   2   3
# 3        33   6   2   3
# 4        33   6   2   3
# ...     ...  ..  ..  ..
# 38696    28   9   1   1
# 38697    28   9   1   1
# 38698    28   9   1   1
# 38699    28   9   1   1
# 38700    28   9   1   1
#
# [38701 rows x 4 columns]
